# %%
from combine_data import *
import os
import pandas as pd

# %%
# Get list of all folders, excluding hidden folders
folders = [item for item in os.listdir('.') if os.path.isdir(item) and not ((item.startswith('.')) or (item.startswith('_')))]

print(folders)
# Out:
# ['Exp 1A', 'Exp 1B', 'Exp 2A', 'Exp 2B', 'Exp 2C', 'Exp 2D', 'Exp 2E', 'Exp 3']

# %%
example_dataframe = open_file('Exp 1A', '1.csv')
print(example_dataframe.head())
# Out:
#    C1  C2  C3   C4  C5        C6        C7        C8  C9
# 0   1   1   2  new   1  0.800000  0.916113  1.436993   3
# 1   2   4   4  old   0  0.516667  0.817099  0.000000   3
# 2   3   1   2  new   1  0.983333  0.715572  1.684502   3
# 3   4   1   1  old   0  0.866667  0.516512  1.203667   3
# 4   5   1   2  new   1  0.916667  0.816399  0.870883   3

# %%
filt_df = isolate_column_by_value(example_dataframe, 'Exp 1A', 1, 2)
print(filt_df)
# Out:
#       C1  C2  C3   C4  C5        C6        C7        C8  C9
# 29    30   1   1  old   0  1.266667  0.916718  1.626431   1
# 32    33   1   2  new   0  0.900000  1.015561  1.340913   1
# 33    34   1   2  new   0  1.383333  0.916589  1.254948   1
# 34    35   1   1  old   0  0.933333  0.716325  1.336008   1
# 36    37   1   2  new   0  0.750000  0.517333  1.592750   1
# 37    38   4   4  old   0  1.166667  0.916296  0.000000   1
# 39    40   1   1  old   0  0.783333  0.716469  1.396741   1
# 43    44   1   1  old   0  0.900000  0.716826  1.298185   1
# 44    45   1   2  new   0  1.483333  1.017018  1.064408   1
# 45    46   4   4  old   0  1.366667  0.916470  0.000000   1
# 47    48   1   1  old   0  1.450000  1.017321  1.060042   1
# 49    50   1   1  old   0  1.466667  0.917389  0.849177   1
# 51    52   1   2  new   0  1.183333  0.516232  0.891101   1
# 54    55   1   2  new   0  0.733333  0.917391  1.349291   1
# 57    58   1   2  new   0  0.966667  0.917392  0.854918   1
# 58    59   1   2  new   0  1.466667  0.916878  1.139940   1
# 91    92   1   2  new   0  1.183333  0.516836  0.931666   1
# 92    93   1   1  old   0  0.683333  0.516161  0.937511   1
# 95    96   1   2  new   0  1.483333  0.617169  1.025942   1
# 96    97   1   2  new   0  0.516667  0.816782  0.871070   1
# 99   100   1   2  new   0  0.616667  0.816912  1.091172   1
# 103  104   1   2  new   0  0.950000  0.815884  0.911859   1
# 105  106   1   1  old   0  1.350000  1.017115  1.405969   1
# 109  110   1   2  new   0  1.233333  0.616960  0.813107   1
# 110  111   1   1  old   0  0.983333  0.816055  0.897036   1
# 111  112   1   2  new   0  1.350000  1.017170  0.733070   1
# 114  115   1   1  old   0  1.133333  0.616354  0.952574   1

# %%
filt_acc = get_average(filt_df, 'Exp 1A')
filt_rt = get_rt(filt_df, 'Exp 1A')
print(filt_acc, filt_rt)
# Out:
# 1.0 1.06004229304381
